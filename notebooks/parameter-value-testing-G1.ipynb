# %%
import mujoco
import numpy as np
import mujoco.viewer as mv

# Load G1 form MJCF fromat
model = mujoco.MjModel.from_xml_path("models/G1/g1_29dof_rev_1_0.xml")
print("✅ Model loaded from XML(MJCF)!")
data = mujoco.MjData(model)
