# %% [markdown]
# ### Importing libararies

# %%
import mujoco
import numpy as np
import mujoco.viewer as mv
import os

# %% [markdown]
# #### Creating base path execution

# %%
# for local execution
NOTEBOOK_PATH = os.getcwd()
BASE_PATH = 
print(BASE_PATH)
xml_path = os.path.join(BASE_PATH, "models/G1/g1_29dof_rev_1_0.xml")
if not os.path.exists(xml_path):
    raise FileNotFoundError(f"❌ File not found at: {xml_path}")
# Out:
# /home/blank/Projects/Internship/sentienc/Robotic-Simulation/robot_ws/mujoco-experiments/notebooks
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 xml_path = os.path.join(BASE_PATH, "models/G1/g1_29dof_rev_1_0.xml")
#       5 if not os.path.exists(xml_path):
# ----> 6     raise FileNotFoundError(f"❌ File not found at: {xml_path}")
#
# FileNotFoundError: ❌ File not found at: /home/blank/Projects/Internship/sentienc/Robotic-Simulation/robot_ws/mujoco-experiments/notebooks/models/G1/g1_29dof_rev_1_0.xml
